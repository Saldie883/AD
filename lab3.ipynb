# %%
from sklearn.tree import DecisionTreeClassifier
clf_tree = DecisionTreeClassifier(criterion='entropy', max_depth=2, random_state=17)

            
df_model =   [[2.387, 1.445,    4.25,  8.45,   36.70, 20.895],
              [1.167,  1.130,    2.75,  8.90,   38.60, 19.835],
              [1.967,  0.595,    1.50, 12.55,   35.75, 21.445],
              [2.877,  1.260,    3.50, 10.05,   38.45, 21.990],
              [2.451,  0.595,    1.25, 11.95,   35.10, 23.170],
              [2.408,  1.360,    4.00, 11.75,   38.25, 21.160],
              [2.699,  1.300,    3.00, 11.75,   37.35, 21.700],
              [2.457,  0.955,    3.25, 10.00,   35.20, 21.145],
              [2.567,  1.030,    3.00, 11.25,   35.90, 21.495],
              [2.984,  1.155,    3.75, 10.85,   39.70, 20.430],
              [1.253,  1.015,    3.25,  8.85,   39.50, 18.850],
              [2.282, 1.450,    4.25,  9.95,   37.55, 20.740],
              [0.468,  1.155,    2.25, 10.80,   37.80, 20.355],
              [1.445,  1.235,    1.50, 10.60,   38.70, 20.385],
              [1.338,  1.120,    2.00, 11.95,   37.80, 20.780],
              [0.913,  1.105,    2.25, 11.00,   37.40, 19.920],
              [1.239,  1.130,    2.00, 10.25,   37.85, 20.290],
              [0.385,  1.120,    2.25,  6.15,   38.50, 17.880],
              [1.108,  1.040,    1.75,  8.30,   37.90, 20.050],
              [1.796,  1.045,    2.00, 11.85,   38.35, 19.745],
              [2.263,  0.750,    2.25,  9.25,   34.25, 22.330],
              [2.164,  0.710,    2.00,  9.35,   37.60, 22.445],
              [2.354,  0.685,    1.50, 11.90,   35.50, 23.680],
              [2.125,  0.710,    1.50, 12.75,   34.35, 23.175],
              [2.583,  0.710,    1.25, 12.70,   33.20, 24.820],
              [2.392,  1.335,    3.50, 11.00,   37.50, 22.130],
              [2.354,  0.645,    1.50, 12.75,   34.15, 24.100],
              [2.567,  1.460,    3.75, 10.85,   37.80, 21.295],
              [2.236,  0.710,    1.50, 10.60,   34.55, 23.100],
              [1.636,  0.595,    1.00,  9.50,   33.70, 22.045]]


objects = ['Lawes', 'Brookstead' , 'Nambour', 'Lawes', 'Nambour', 'Lawes', 'Lawes', 'Lawes', 'Lawes', 'Lawes', 
     'Brookstead', 'Lawes', 'Brookstead', 'Brookstead', 'Brookstead','Brookstead','Brookstead', 'Brookstead', 'Brookstead', 'Brookstead', 
     'Nambour' , 'Nambour', 'Lawes', 'Nambour', 'Nambour', 'Lawes', 'Nambour','Lawes', 'Nambour', 'Nambour']
clf_tree.fit(df_model, objects)

from sklearn import tree
from IPython.display import Image
import pydotplus

result = tree.export_graphviz(clf_tree, out_file=None)
graph = pydotplus.graph_from_dot_data(result)
tree.plot_tree(clf_tree)
# Out:
# [Text(167.4, 181.2, 'X[0] <= 1.882\nentropy = 1.58\nsamples = 30\nvalue = [10, 11, 9]'),
#  Text(83.7, 108.72, 'X[5] <= 21.413\nentropy = 0.439\nsamples = 11\nvalue = [10, 0, 1]'),
#  Text(41.85, 36.23999999999998, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(125.55000000000001, 36.23999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(251.10000000000002, 108.72, 'X[2] <= 2.625\nentropy = 0.982\nsamples = 19\nvalue = [0, 11, 8]'),
#  Text(209.25, 36.23999999999998, 'entropy = 0.503\nsamples = 9\nvalue = [0, 1, 8]'),
#  Text(292.95, 36.23999999999998, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10, 0]')]
